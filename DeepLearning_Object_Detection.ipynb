# %%
# !pip install ultralytics

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="nCUp9bnQf5a79JioXKC7")
project = rf.workspace("luca-vziny").project("people-4evn7")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.29, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to People-1 in yolov8:: 100%|██████████| 3386/3386 [00:00<00:00, 6557.84it/s]

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.1/78.2 GB disk)

# %%
# !yolo detect train data = /content/People-1/data.yaml
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train3/weights/best.pt source='/content/drive/MyDrive/sample gambar/flora.jpg' save=true
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/sample gambar/flora.jpg: 640x512 2 Peoples, 62.1ms
# Speed: 2.6ms preprocess, 62.1ms inference, 523.9ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model=/content/runs/detect/train3/weights/best.pt source='https://www.investorsinpeople.com/wp-content/uploads/2022/04/shutterstock_236097745.jpg' save=true
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# ...
# 100% 52.4k/52.4k [00:00<00:00, 404kB/s]
# image 1/1 /content/shutterstock_236097745.jpg: 480x640 3 Peoples, 92.2ms
# Speed: 4.8ms preprocess, 92.2ms inference, 551.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
